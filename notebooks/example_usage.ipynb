# %% [markdown]
# Lets create some example code for using the package I've written.

# %%
#Import the tools.
from utils.confusion_matrix_generalized import CMGeneralized
from utils.cm_generator import CMGenerator
from utils.contingency_space import ContingencySpace
from metrics.imbalance_sensitivity import imbalance_sensitivity
import numpy as np
import math

# %% [markdown]
# The glue that holds all of these pieces together is the Confusion Matrix, which can be constructed like so:

# %%
#Where the keys can lists come together to represent a row of a confusion matrix. 
matrix = CMGeneralized({
    't': [500, 500],
    'f': [500, 500]
})

# %% [markdown]
# It can also be built row by row:

# %%
matrix = CMGeneralized()
matrix.add_class('f', [500, 500])
matrix.add_class('f', [500, 500])

print(matrix.array())
# Out:
# [[500 500]]

# %% [markdown]
# The matrix contains a few functions that can be useful. We will come back to this later. Let's take a look at the class I put together to demonstrate their usage:

# %%
#Let's generate some data to generate some confusion matrices.
num_classes: int = 2
total_instances: int = 1000
instances_per_class: dict[str, int] = {'t': 500, 'f': 500} #This is the number of total instances per class, not necessarily the hits, however.

generator = CMGenerator(num_classes, total_instances, instances_per_class) #here we pass this data to the constructor.

# %% [markdown]
# To generate the matrices, we will tell the generator the
# "granularity" of matrices we wish to generate.
# What this represents is the number of points on each axis we wish to generate.
# So for instance, with a binary classification problem and a granularity of 10, we will generate 100 total matrices 10^n for n number of classes.
#
# For example, if a given class has 100 instances, and we give a granularity of 10, these points will be generated for that axis: 10% correct, 20% correct, 30%, etc.

# %%
#granularity: The resolution at which we will generate matrices. 
granularity: int = 10
generator.generate_cms(granularity)
# Out:
# [     t    f
#  t    0  500
#  f  500    0,
#       t    f
#  t    0  500
#  f  445   55,
#       t    f
#  t    0  500
#  f  389  111,
#       t    f
#  t    0  500
#  f  334  166,
#       t    f
#  t    0  500
#  f  278  222,
#       t    f
#  t    0  500
#  f  223  277,
#       t    f
#  t    0  500
#  f  167  333,
#       t    f
#  t    0  500
#  f  112  388,
#      t    f
#  t   0  500
#  f  56  444,
#     t    f
#  t  0  500
#  f  0  500,
#       t    f
#  t   55  445
#  f  500    0,
#       t    f
#  t   55  445
#  f  445   55,
#       t    f
#  t   55  445
#  f  389  111,
#       t    f
#  t   55  445
#  f  334  166,
#       t    f
#  t   55  445
#  f  278  222,
#       t    f
#  t   55  445
#  f  223  277,
#       t    f
#  t   55  445
#  f  167  333,
#       t    f
#  t   55  445
#  f  112  388,
#      t    f
#  t  55  445
#  f  56  444,
#      t    f
#  t  55  445
#  f   0  500,
#       t    f
#  t  111  389
#  f  500    0,
#       t    f
#  t  111  389
#  f  445   55,
#       t    f
#  t  111  389
#  f  389  111,
#       t    f
#  t  111  389
#  f  334  166,
#       t    f
#  t  111  389
#  f  278  222,
#       t    f
#  t  111  389
#  f  223  277,
#       t    f
#  t  111  389
#  f  167  333,
#       t    f
#  t  111  389
#  f  112  388,
#       t    f
#  t  111  389
#  f   56  444,
#       t    f
#  t  111  389
#  f    0  500,
#       t    f
#  t  166  334
#  f  500    0,
#       t    f
#  t  166  334
#  f  445   55,
#       t    f
#  t  166  334
#  f  389  111,
#       t    f
#  t  166  334
#  f  334  166,
#       t    f
#  t  166  334
#  f  278  222,
#       t    f
#  t  166  334
#  f  223  277,
#       t    f
#  t  166  334
#  f  167  333,
#       t    f
#  t  166  334
#  f  112  388,
#       t    f
#  t  166  334
#  f   56  444,
#       t    f
#  t  166  334
#  f    0  500,
#       t    f
#  t  222  278
#  f  500    0,
#       t    f
#  t  222  278
#  f  445   55,
#       t    f
#  t  222  278
#  f  389  111,
#       t    f
#  t  222  278
#  f  334  166,
#       t    f
#  t  222  278
#  f  278  222,
#       t    f
#  t  222  278
#  f  223  277,
#       t    f
#  t  222  278
#  f  167  333,
#       t    f
#  t  222  278
#  f  112  388,
#       t    f
#  t  222  278
#  f   56  444,
#       t    f
#  t  222  278
#  f    0  500,
#       t    f
#  t  277  223
#  f  500    0,
#       t    f
#  t  277  223
#  f  445   55,
#       t    f
#  t  277  223
#  f  389  111,
#       t    f
#  t  277  223
#  f  334  166,
#       t    f
#  t  277  223
#  f  278  222,
#       t    f
#  t  277  223
#  f  223  277,
#       t    f
#  t  277  223
#  f  167  333,
#       t    f
#  t  277  223
#  f  112  388,
#       t    f
#  t  277  223
#  f   56  444,
#       t    f
#  t  277  223
#  f    0  500,
#       t    f
#  t  333  167
#  f  500    0,
#       t    f
#  t  333  167
#  f  445   55,
#       t    f
#  t  333  167
#  f  389  111,
#       t    f
#  t  333  167
#  f  334  166,
#       t    f
#  t  333  167
#  f  278  222,
#       t    f
#  t  333  167
#  f  223  277,
#       t    f
#  t  333  167
#  f  167  333,
#       t    f
#  t  333  167
#  f  112  388,
#       t    f
#  t  333  167
#  f   56  444,
#       t    f
#  t  333  167
#  f    0  500,
#       t    f
#  t  388  112
#  f  500    0,
#       t    f
#  t  388  112
#  f  445   55,
#       t    f
#  t  388  112
#  f  389  111,
#       t    f
#  t  388  112
#  f  334  166,
#       t    f
#  t  388  112
#  f  278  222,
#       t    f
#  t  388  112
#  f  223  277,
#       t    f
#  t  388  112
#  f  167  333,
#       t    f
#  t  388  112
#  f  112  388,
#       t    f
#  t  388  112
#  f   56  444,
#       t    f
#  t  388  112
#  f    0  500,
#       t   f
#  t  444  56
#  f  500   0,
#       t   f
#  t  444  56
#  f  445  55,
#       t    f
#  t  444   56
#  f  389  111,
#       t    f
#  t  444   56
#  f  334  166,
#       t    f
#  t  444   56
#  f  278  222,
#       t    f
#  t  444   56
#  f  223  277,
#       t    f
#  t  444   56
#  f  167  333,
#       t    f
#  t  444   56
#  f  112  388,
#       t    f
#  t  444   56
#  f   56  444,
#       t    f
#  t  444   56
#  f    0  500,
#       t  f
#  t  500  0
#  f  500  0,
#       t   f
#  t  500   0
#  f  445  55,
#       t    f
#  t  500    0
#  f  389  111,
#       t    f
#  t  500    0
#  f  334  166,
#       t    f
#  t  500    0
#  f  278  222,
#       t    f
#  t  500    0
#  f  223  277,
#       t    f
#  t  500    0
#  f  167  333,
#       t    f
#  t  500    0
#  f  112  388,
#       t    f
#  t  500    0
#  f   56  444,
#       t    f
#  t  500    0
#  f    0  500]

# %% [markdown]
# We can now view the matrices generated by using CMGenerator.show_all_cms().

# %%
generator.show_all_cms()
# Out:
# --[0]-----------------------------------------
#      t    f
# t    0  500
# f  500    0
# --[1]-----------------------------------------
#      t    f
# t    0  500
# f  445   55
# --[2]-----------------------------------------
#      t    f
# t    0  500
# f  389  111
# --[3]-----------------------------------------
#      t    f
# t    0  500
# f  334  166
# --[4]-----------------------------------------
#      t    f
# t    0  500
# f  278  222
# --[5]-----------------------------------------
#      t    f
# t    0  500
# f  223  277
# --[6]-----------------------------------------
#      t    f
# t    0  500
# f  167  333
# --[7]-----------------------------------------
#      t    f
# t    0  500
# f  112  388
# --[8]-----------------------------------------
#     t    f
# t   0  500
# f  56  444
# --[9]-----------------------------------------
#    t    f
# t  0  500
# f  0  500
# --[10]-----------------------------------------
#      t    f
# t   55  445
# f  500    0
# --[11]-----------------------------------------
#      t    f
# t   55  445
# f  445   55
# --[12]-----------------------------------------
#      t    f
# t   55  445
# f  389  111
# --[13]-----------------------------------------
#      t    f
# t   55  445
# f  334  166
# --[14]-----------------------------------------
#      t    f
# t   55  445
# f  278  222
# --[15]-----------------------------------------
#      t    f
# t   55  445
# f  223  277
# --[16]-----------------------------------------
#      t    f
# t   55  445
# f  167  333
# --[17]-----------------------------------------
#      t    f
# t   55  445
# f  112  388
# --[18]-----------------------------------------
#     t    f
# t  55  445
# f  56  444
# --[19]-----------------------------------------
#     t    f
# t  55  445
# f   0  500
# --[20]-----------------------------------------
#      t    f
# t  111  389
# f  500    0
# --[21]-----------------------------------------
#      t    f
# t  111  389
# f  445   55
# --[22]-----------------------------------------
#      t    f
# t  111  389
# f  389  111
# --[23]-----------------------------------------
#      t    f
# t  111  389
# f  334  166
# --[24]-----------------------------------------
#      t    f
# t  111  389
# f  278  222
# --[25]-----------------------------------------
#      t    f
# t  111  389
# f  223  277
# --[26]-----------------------------------------
#      t    f
# t  111  389
# f  167  333
# --[27]-----------------------------------------
#      t    f
# t  111  389
# f  112  388
# --[28]-----------------------------------------
#      t    f
# t  111  389
# f   56  444
# --[29]-----------------------------------------
#      t    f
# t  111  389
# f    0  500
# --[30]-----------------------------------------
#      t    f
# t  166  334
# f  500    0
# --[31]-----------------------------------------
#      t    f
# t  166  334
# f  445   55
# --[32]-----------------------------------------
#      t    f
# t  166  334
# f  389  111
# --[33]-----------------------------------------
#      t    f
# t  166  334
# f  334  166
# --[34]-----------------------------------------
#      t    f
# t  166  334
# f  278  222
# --[35]-----------------------------------------
#      t    f
# t  166  334
# f  223  277
# --[36]-----------------------------------------
#      t    f
# t  166  334
# f  167  333
# --[37]-----------------------------------------
#      t    f
# t  166  334
# f  112  388
# --[38]-----------------------------------------
#      t    f
# t  166  334
# f   56  444
# --[39]-----------------------------------------
#      t    f
# t  166  334
# f    0  500
# --[40]-----------------------------------------
#      t    f
# t  222  278
# f  500    0
# --[41]-----------------------------------------
#      t    f
# t  222  278
# f  445   55
# --[42]-----------------------------------------
#      t    f
# t  222  278
# f  389  111
# --[43]-----------------------------------------
#      t    f
# t  222  278
# f  334  166
# --[44]-----------------------------------------
#      t    f
# t  222  278
# f  278  222
# --[45]-----------------------------------------
#      t    f
# t  222  278
# f  223  277
# --[46]-----------------------------------------
#      t    f
# t  222  278
# f  167  333
# --[47]-----------------------------------------
#      t    f
# t  222  278
# f  112  388
# --[48]-----------------------------------------
#      t    f
# t  222  278
# f   56  444
# --[49]-----------------------------------------
#      t    f
# t  222  278
# f    0  500
# --[50]-----------------------------------------
#      t    f
# t  277  223
# f  500    0
# --[51]-----------------------------------------
#      t    f
# t  277  223
# f  445   55
# --[52]-----------------------------------------
#      t    f
# t  277  223
# f  389  111
# --[53]-----------------------------------------
#      t    f
# t  277  223
# f  334  166
# --[54]-----------------------------------------
#      t    f
# t  277  223
# f  278  222
# --[55]-----------------------------------------
#      t    f
# t  277  223
# f  223  277
# --[56]-----------------------------------------
#      t    f
# t  277  223
# f  167  333
# --[57]-----------------------------------------
#      t    f
# t  277  223
# f  112  388
# --[58]-----------------------------------------
#      t    f
# t  277  223
# f   56  444
# --[59]-----------------------------------------
#      t    f
# t  277  223
# f    0  500
# --[60]-----------------------------------------
#      t    f
# t  333  167
# f  500    0
# --[61]-----------------------------------------
#      t    f
# t  333  167
# f  445   55
# --[62]-----------------------------------------
#      t    f
# t  333  167
# f  389  111
# --[63]-----------------------------------------
#      t    f
# t  333  167
# f  334  166
# --[64]-----------------------------------------
#      t    f
# t  333  167
# f  278  222
# --[65]-----------------------------------------
#      t    f
# t  333  167
# f  223  277
# --[66]-----------------------------------------
#      t    f
# t  333  167
# f  167  333
# --[67]-----------------------------------------
#      t    f
# t  333  167
# f  112  388
# --[68]-----------------------------------------
#      t    f
# t  333  167
# f   56  444
# --[69]-----------------------------------------
#      t    f
# t  333  167
# f    0  500
# --[70]-----------------------------------------
#      t    f
# t  388  112
# f  500    0
# --[71]-----------------------------------------
#      t    f
# t  388  112
# f  445   55
# --[72]-----------------------------------------
#      t    f
# t  388  112
# f  389  111
# --[73]-----------------------------------------
#      t    f
# t  388  112
# f  334  166
# --[74]-----------------------------------------
#      t    f
# t  388  112
# f  278  222
# --[75]-----------------------------------------
#      t    f
# t  388  112
# f  223  277
# --[76]-----------------------------------------
#      t    f
# t  388  112
# f  167  333
# --[77]-----------------------------------------
#      t    f
# t  388  112
# f  112  388
# --[78]-----------------------------------------
#      t    f
# t  388  112
# f   56  444
# --[79]-----------------------------------------
#      t    f
# t  388  112
# f    0  500
# --[80]-----------------------------------------
#      t   f
# t  444  56
# f  500   0
# --[81]-----------------------------------------
#      t   f
# t  444  56
# f  445  55
# --[82]-----------------------------------------
#      t    f
# t  444   56
# f  389  111
# --[83]-----------------------------------------
#      t    f
# t  444   56
# f  334  166
# --[84]-----------------------------------------
#      t    f
# t  444   56
# f  278  222
# --[85]-----------------------------------------
#      t    f
# t  444   56
# f  223  277
# --[86]-----------------------------------------
#      t    f
# t  444   56
# f  167  333
# --[87]-----------------------------------------
#      t    f
# t  444   56
# f  112  388
# --[88]-----------------------------------------
#      t    f
# t  444   56
# f   56  444
# --[89]-----------------------------------------
#      t    f
# t  444   56
# f    0  500
# --[90]-----------------------------------------
#      t  f
# t  500  0
# f  500  0
# --[91]-----------------------------------------
#      t   f
# t  500   0
# f  445  55
# --[92]-----------------------------------------
#      t    f
# t  500    0
# f  389  111
# --[93]-----------------------------------------
#      t    f
# t  500    0
# f  334  166
# --[94]-----------------------------------------
#      t    f
# t  500    0
# f  278  222
# --[95]-----------------------------------------
#      t    f
# t  500    0
# f  223  277
# --[96]-----------------------------------------
#      t    f
# t  500    0
# f  167  333
# --[97]-----------------------------------------
#      t    f
# t  500    0
# f  112  388
# --[98]-----------------------------------------
#      t    f
# t  500    0
# f   56  444
# --[99]-----------------------------------------
#      t    f
# t  500    0
# f    0  500

# %% [markdown]
# Now, lets do the same thing for an imbalanced problem.

# %%
num_classes = 2
num_classes: int = 2
total_instances: int = 1300
instances_per_class: dict[str, int] = {'t': 800, 'f': 500}

generator = CMGenerator(num_classes, total_instances, instances_per_class)

# %%
#granularity: The resolution at which we will generate matrices. 
granularity: int = 10
generator.generate_cms(granularity)
# Out:
# [     t    f
#  t    0  800
#  f  500    0,
#       t    f
#  t    0  800
#  f  445   55,
#       t    f
#  t    0  800
#  f  389  111,
#       t    f
#  t    0  800
#  f  334  166,
#       t    f
#  t    0  800
#  f  278  222,
#       t    f
#  t    0  800
#  f  223  277,
#       t    f
#  t    0  800
#  f  167  333,
#       t    f
#  t    0  800
#  f  112  388,
#      t    f
#  t   0  800
#  f  56  444,
#     t    f
#  t  0  800
#  f  0  500,
#       t    f
#  t   88  712
#  f  500    0,
#       t    f
#  t   88  712
#  f  445   55,
#       t    f
#  t   88  712
#  f  389  111,
#       t    f
#  t   88  712
#  f  334  166,
#       t    f
#  t   88  712
#  f  278  222,
#       t    f
#  t   88  712
#  f  223  277,
#       t    f
#  t   88  712
#  f  167  333,
#       t    f
#  t   88  712
#  f  112  388,
#      t    f
#  t  88  712
#  f  56  444,
#      t    f
#  t  88  712
#  f   0  500,
#       t    f
#  t  177  623
#  f  500    0,
#       t    f
#  t  177  623
#  f  445   55,
#       t    f
#  t  177  623
#  f  389  111,
#       t    f
#  t  177  623
#  f  334  166,
#       t    f
#  t  177  623
#  f  278  222,
#       t    f
#  t  177  623
#  f  223  277,
#       t    f
#  t  177  623
#  f  167  333,
#       t    f
#  t  177  623
#  f  112  388,
#       t    f
#  t  177  623
#  f   56  444,
#       t    f
#  t  177  623
#  f    0  500,
#       t    f
#  t  266  534
#  f  500    0,
#       t    f
#  t  266  534
#  f  445   55,
#       t    f
#  t  266  534
#  f  389  111,
#       t    f
#  t  266  534
#  f  334  166,
#       t    f
#  t  266  534
#  f  278  222,
#       t    f
#  t  266  534
#  f  223  277,
#       t    f
#  t  266  534
#  f  167  333,
#       t    f
#  t  266  534
#  f  112  388,
#       t    f
#  t  266  534
#  f   56  444,
#       t    f
#  t  266  534
#  f    0  500,
#       t    f
#  t  355  445
#  f  500    0,
#       t    f
#  t  355  445
#  f  445   55,
#       t    f
#  t  355  445
#  f  389  111,
#       t    f
#  t  355  445
#  f  334  166,
#       t    f
#  t  355  445
#  f  278  222,
#       t    f
#  t  355  445
#  f  223  277,
#       t    f
#  t  355  445
#  f  167  333,
#       t    f
#  t  355  445
#  f  112  388,
#       t    f
#  t  355  445
#  f   56  444,
#       t    f
#  t  355  445
#  f    0  500,
#       t    f
#  t  444  356
#  f  500    0,
#       t    f
#  t  444  356
#  f  445   55,
#       t    f
#  t  444  356
#  f  389  111,
#       t    f
#  t  444  356
#  f  334  166,
#       t    f
#  t  444  356
#  f  278  222,
#       t    f
#  t  444  356
#  f  223  277,
#       t    f
#  t  444  356
#  f  167  333,
#       t    f
#  t  444  356
#  f  112  388,
#       t    f
#  t  444  356
#  f   56  444,
#       t    f
#  t  444  356
#  f    0  500,
#       t    f
#  t  533  267
#  f  500    0,
#       t    f
#  t  533  267
#  f  445   55,
#       t    f
#  t  533  267
#  f  389  111,
#       t    f
#  t  533  267
#  f  334  166,
#       t    f
#  t  533  267
#  f  278  222,
#       t    f
#  t  533  267
#  f  223  277,
#       t    f
#  t  533  267
#  f  167  333,
#       t    f
#  t  533  267
#  f  112  388,
#       t    f
#  t  533  267
#  f   56  444,
#       t    f
#  t  533  267
#  f    0  500,
#       t    f
#  t  622  178
#  f  500    0,
#       t    f
#  t  622  178
#  f  445   55,
#       t    f
#  t  622  178
#  f  389  111,
#       t    f
#  t  622  178
#  f  334  166,
#       t    f
#  t  622  178
#  f  278  222,
#       t    f
#  t  622  178
#  f  223  277,
#       t    f
#  t  622  178
#  f  167  333,
#       t    f
#  t  622  178
#  f  112  388,
#       t    f
#  t  622  178
#  f   56  444,
#       t    f
#  t  622  178
#  f    0  500,
#       t   f
#  t  711  89
#  f  500   0,
#       t   f
#  t  711  89
#  f  445  55,
#       t    f
#  t  711   89
#  f  389  111,
#       t    f
#  t  711   89
#  f  334  166,
#       t    f
#  t  711   89
#  f  278  222,
#       t    f
#  t  711   89
#  f  223  277,
#       t    f
#  t  711   89
#  f  167  333,
#       t    f
#  t  711   89
#  f  112  388,
#       t    f
#  t  711   89
#  f   56  444,
#       t    f
#  t  711   89
#  f    0  500,
#       t  f
#  t  800  0
#  f  500  0,
#       t   f
#  t  800   0
#  f  445  55,
#       t    f
#  t  800    0
#  f  389  111,
#       t    f
#  t  800    0
#  f  334  166,
#       t    f
#  t  800    0
#  f  278  222,
#       t    f
#  t  800    0
#  f  223  277,
#       t    f
#  t  800    0
#  f  167  333,
#       t    f
#  t  800    0
#  f  112  388,
#       t    f
#  t  800    0
#  f   56  444,
#       t    f
#  t  800    0
#  f    0  500]

# %%
generator.show_all_cms()
# Out:
# --[0]-----------------------------------------
#      t    f
# t    0  800
# f  500    0
# --[1]-----------------------------------------
#      t    f
# t    0  800
# f  445   55
# --[2]-----------------------------------------
#      t    f
# t    0  800
# f  389  111
# --[3]-----------------------------------------
#      t    f
# t    0  800
# f  334  166
# --[4]-----------------------------------------
#      t    f
# t    0  800
# f  278  222
# --[5]-----------------------------------------
#      t    f
# t    0  800
# f  223  277
# --[6]-----------------------------------------
#      t    f
# t    0  800
# f  167  333
# --[7]-----------------------------------------
#      t    f
# t    0  800
# f  112  388
# --[8]-----------------------------------------
#     t    f
# t   0  800
# f  56  444
# --[9]-----------------------------------------
#    t    f
# t  0  800
# f  0  500
# --[10]-----------------------------------------
#      t    f
# t   88  712
# f  500    0
# --[11]-----------------------------------------
#      t    f
# t   88  712
# f  445   55
# --[12]-----------------------------------------
#      t    f
# t   88  712
# f  389  111
# --[13]-----------------------------------------
#      t    f
# t   88  712
# f  334  166
# --[14]-----------------------------------------
#      t    f
# t   88  712
# f  278  222
# --[15]-----------------------------------------
#      t    f
# t   88  712
# f  223  277
# --[16]-----------------------------------------
#      t    f
# t   88  712
# f  167  333
# --[17]-----------------------------------------
#      t    f
# t   88  712
# f  112  388
# --[18]-----------------------------------------
#     t    f
# t  88  712
# f  56  444
# --[19]-----------------------------------------
#     t    f
# t  88  712
# f   0  500
# --[20]-----------------------------------------
#      t    f
# t  177  623
# f  500    0
# --[21]-----------------------------------------
#      t    f
# t  177  623
# f  445   55
# --[22]-----------------------------------------
#      t    f
# t  177  623
# f  389  111
# --[23]-----------------------------------------
#      t    f
# t  177  623
# f  334  166
# --[24]-----------------------------------------
#      t    f
# t  177  623
# f  278  222
# --[25]-----------------------------------------
#      t    f
# t  177  623
# f  223  277
# --[26]-----------------------------------------
#      t    f
# t  177  623
# f  167  333
# --[27]-----------------------------------------
#      t    f
# t  177  623
# f  112  388
# --[28]-----------------------------------------
#      t    f
# t  177  623
# f   56  444
# --[29]-----------------------------------------
#      t    f
# t  177  623
# f    0  500
# --[30]-----------------------------------------
#      t    f
# t  266  534
# f  500    0
# --[31]-----------------------------------------
#      t    f
# t  266  534
# f  445   55
# --[32]-----------------------------------------
#      t    f
# t  266  534
# f  389  111
# --[33]-----------------------------------------
#      t    f
# t  266  534
# f  334  166
# --[34]-----------------------------------------
#      t    f
# t  266  534
# f  278  222
# --[35]-----------------------------------------
#      t    f
# t  266  534
# f  223  277
# --[36]-----------------------------------------
#      t    f
# t  266  534
# f  167  333
# --[37]-----------------------------------------
#      t    f
# t  266  534
# f  112  388
# --[38]-----------------------------------------
#      t    f
# t  266  534
# f   56  444
# --[39]-----------------------------------------
#      t    f
# t  266  534
# f    0  500
# --[40]-----------------------------------------
#      t    f
# t  355  445
# f  500    0
# --[41]-----------------------------------------
#      t    f
# t  355  445
# f  445   55
# --[42]-----------------------------------------
#      t    f
# t  355  445
# f  389  111
# --[43]-----------------------------------------
#      t    f
# t  355  445
# f  334  166
# --[44]-----------------------------------------
#      t    f
# t  355  445
# f  278  222
# --[45]-----------------------------------------
#      t    f
# t  355  445
# f  223  277
# --[46]-----------------------------------------
#      t    f
# t  355  445
# f  167  333
# --[47]-----------------------------------------
#      t    f
# t  355  445
# f  112  388
# --[48]-----------------------------------------
#      t    f
# t  355  445
# f   56  444
# --[49]-----------------------------------------
#      t    f
# t  355  445
# f    0  500
# --[50]-----------------------------------------
#      t    f
# t  444  356
# f  500    0
# --[51]-----------------------------------------
#      t    f
# t  444  356
# f  445   55
# --[52]-----------------------------------------
#      t    f
# t  444  356
# f  389  111
# --[53]-----------------------------------------
#      t    f
# t  444  356
# f  334  166
# --[54]-----------------------------------------
#      t    f
# t  444  356
# f  278  222
# --[55]-----------------------------------------
#      t    f
# t  444  356
# f  223  277
# --[56]-----------------------------------------
#      t    f
# t  444  356
# f  167  333
# --[57]-----------------------------------------
#      t    f
# t  444  356
# f  112  388
# --[58]-----------------------------------------
#      t    f
# t  444  356
# f   56  444
# --[59]-----------------------------------------
#      t    f
# t  444  356
# f    0  500
# --[60]-----------------------------------------
#      t    f
# t  533  267
# f  500    0
# --[61]-----------------------------------------
#      t    f
# t  533  267
# f  445   55
# --[62]-----------------------------------------
#      t    f
# t  533  267
# f  389  111
# --[63]-----------------------------------------
#      t    f
# t  533  267
# f  334  166
# --[64]-----------------------------------------
#      t    f
# t  533  267
# f  278  222
# --[65]-----------------------------------------
#      t    f
# t  533  267
# f  223  277
# --[66]-----------------------------------------
#      t    f
# t  533  267
# f  167  333
# --[67]-----------------------------------------
#      t    f
# t  533  267
# f  112  388
# --[68]-----------------------------------------
#      t    f
# t  533  267
# f   56  444
# --[69]-----------------------------------------
#      t    f
# t  533  267
# f    0  500
# --[70]-----------------------------------------
#      t    f
# t  622  178
# f  500    0
# --[71]-----------------------------------------
#      t    f
# t  622  178
# f  445   55
# --[72]-----------------------------------------
#      t    f
# t  622  178
# f  389  111
# --[73]-----------------------------------------
#      t    f
# t  622  178
# f  334  166
# --[74]-----------------------------------------
#      t    f
# t  622  178
# f  278  222
# --[75]-----------------------------------------
#      t    f
# t  622  178
# f  223  277
# --[76]-----------------------------------------
#      t    f
# t  622  178
# f  167  333
# --[77]-----------------------------------------
#      t    f
# t  622  178
# f  112  388
# --[78]-----------------------------------------
#      t    f
# t  622  178
# f   56  444
# --[79]-----------------------------------------
#      t    f
# t  622  178
# f    0  500
# --[80]-----------------------------------------
#      t   f
# t  711  89
# f  500   0
# --[81]-----------------------------------------
#      t   f
# t  711  89
# f  445  55
# --[82]-----------------------------------------
#      t    f
# t  711   89
# f  389  111
# --[83]-----------------------------------------
#      t    f
# t  711   89
# f  334  166
# --[84]-----------------------------------------
#      t    f
# t  711   89
# f  278  222
# --[85]-----------------------------------------
#      t    f
# t  711   89
# f  223  277
# --[86]-----------------------------------------
#      t    f
# t  711   89
# f  167  333
# --[87]-----------------------------------------
#      t    f
# t  711   89
# f  112  388
# --[88]-----------------------------------------
#      t    f
# t  711   89
# f   56  444
# --[89]-----------------------------------------
#      t    f
# t  711   89
# f    0  500
# --[90]-----------------------------------------
#      t  f
# t  800  0
# f  500  0
# --[91]-----------------------------------------
#      t   f
# t  800   0
# f  445  55
# --[92]-----------------------------------------
#      t    f
# t  800    0
# f  389  111
# --[93]-----------------------------------------
#      t    f
# t  800    0
# f  334  166
# --[94]-----------------------------------------
#      t    f
# t  800    0
# f  278  222
# --[95]-----------------------------------------
#      t    f
# t  800    0
# f  223  277
# --[96]-----------------------------------------
#      t    f
# t  800    0
# f  167  333
# --[97]-----------------------------------------
#      t    f
# t  800    0
# f  112  388
# --[98]-----------------------------------------
#      t    f
# t  800    0
# f   56  444
# --[99]-----------------------------------------
#      t    f
# t  800    0
# f    0  500

# %% [markdown]
# As we've shown, the new Confusion Matrix class, along with the CMGenerator, can be used to show confusion matrices of both balanced and unbalanced binary classification problems. But what about multi-class classification? It can handle that too:

# %%
num_classes = 5
total_instances = 6000
instances_per_class = {'a': 1200, 'b': 800, 'c': 600, 'd': 1800, 'e': 1600}

generator = CMGenerator(num_classes, total_instances, instances_per_class)

# %%
generator.generate_cms(5)
generator.show_all_cms()
# Out:
# --[0]-----------------------------------------
#      a    b    c    d    e
# a    0  300  300  300  300
# b  200    0  200  200  200
# c
-----------------------------------------
#      a    b    c     d    e
# a    0  300  300   300  300
# b  200    0  200   200  200
# c   75   75  300    75   75
# d  112  112  112  1350  112
# e  300  300  300   300  400
# --[67]-----------------------------------------
#      a    b    c     d    e
# a    0  300  300   300  300
# b  200    0  200   200  200
# c   75   75  300    75   75
# d  112  112  112  1350  112
# e  200  200  200   200  800
# --[68]-----------------------------------------
#      a    b    c     d     e
# a    0  300  300   300   300
# b  200    0  200   200   200
# c   75   75  300    75    75
# d  112  112  112  1350   112
# e  100  100  100   100  1200
# --[69]-----------------------------------------
#      a    b    c     d     e
# a    0  300  300   300   300
# b  200    0  200   200   200
# c   75   75  300    75    75
# d  112  112  112  1350   112
# e    0    0    0     0  1600
# --[70]-----------------------------------------
#      a    b    c     d    e
# a    0  300  300   300  300
# b  200    0  200   200  200
# c   75   75  300    75   75
# d    0    0    0  1800    0
# e  400  400  400   400    0
# --[71]-----------------------------------------
#      a    b    c     d    e
# a    0  300  300   300  300
# b  200    0  200   200  200
# c   75   75  300    75   75
# d    0    0    0  1800    0
# e  300  300  300   300  400
# --[72]-----------------------------------------
#      a    b    c     d    e
# a    0  300  300   300  300
# b  200    0  200   200  200
# c   75   75  300    75   75
# d    0    0    0  1800    0
# e  200  200  200   200  800
# --[73]-----------------------------------------
#      a    b    c     d     e
# a    0  300  300   300   300
# b  200    0  200   200   200
# c   75   75  300    75    75
# d    0    0    0  1800     0
# e  100  100  100   100  1200
# --[74]-----------------------------------------
#      a    b    c     d     e
# a    0  300  300   300   300
# b  200    0  200   200   200
# c   75   75  300    75    75
# d    0    0    0  1800     0
# e    0    0    0     0  1600
# --[75]-----------------------------------------
#      a    b    c    d    e
# a    0  300  300  300  300
# b  200    0  200  200  200
# c   37   37  450   37   37
# d  450  450  450    0  450
# e  400  400  400  400    0
# --[76]-----------------------------------------
#      a    b    c    d    e
# a    0  300  300  300  300
# b  200    0  200  200  200
# c   37   37  450   37   37
# d  450  450  450    0  450
# e  300  300  300  300  400
# --[77]-----------------------------------------
#      a    b    c    d    e
# a    0  300  300  300  300
# b  200    0  200  200  200
# c   37   37  450   37   37
# d  450  450  450    0  450
# e  200  200  200  200  800
# --[78]-----------------------------------------
#      a    b    c    d     e
# a    0  300  300  300   300
# b  200    0  200  200   200
# c   37   37  450   37    37
# d  450  450  450    0   450
# e  100  100  100  100  1200
# --[79]-----------------------------------------
#      a    b    c    d     e
# a    0  300  300  300   300
# b  200    0  200  200   200
# c   37   37  450   37    37
# d  450  450  450    0   450
# e    0    0    0    0  1600
# --[80]-----------------------------------------
#      a    b    c    d    e
# a    0  300  300  300  300
# b  200    0  200  200  200
# c   37   37  450   37   37
# d  337  337  337  450  337
# e  400  400  400  400    0
# --[81]-----------------------------------------
#      a    b    c    d    e
# a    0  300  300  300  300
# b  200    0  200  200  200
# c   37   37  450   37   37
# d  337  337  337  450  337
# e  300  300  300  300  400
# --[82]-----------------------------------------
#      a    b    c    d    e
# a    0  300  300  300  300
# b  200    0  200  200  200
# c   37   37  450   37   37
# d  337  337  337  450  337
# e  200  200  200  200  800
# --[83]-----------------------------------------
#      a    b    c    d     e
# a    0  300  300  300   300
# b  200    0  200  200   200
# c   37   37  450   37    37
# d  337  337  337  450   337
# e  100  100  100  100  1200
# --[84]-----------------------------------------
#      a    b    c    d     e
# a    0  300  300  300   300
# b  200    0  200  200   200
# c   37   37  450   37    37
# d  337  337  337  450   337
# e    0    0    0    0  1600
# --[85]-----------------------------------------
#      a    b    c    d    e
# a    0  300  300  300  300
# b  200    0  200  200  200
# c   37   37  450   37   37
# d  225  225  225  900  225
# e  400  400  400  400    0
# --[86]-----------------------------------------
#      a    b    c    d    e
# a    0  300  300  300  300
# b  200    0  200  200  200
# c   37   37  450   37   37
# d  225  225  225  900  225
# e  300  300  300  300  400
# --[87]-----------------------------------------
#      a    b    c    d    e
# a    0  300  300  300  300
# b  200    0  200  200  200
# c   37   37  450   37   37
# d  225  225  225  900  225
# e  200  200  200  200  800
# --[88]-----------------------------------------
#      a    b    c    d     e
# a    0  300  300  300   300
# b  200    0  200  200   200
# c   37   37  450   37    37
# d  225  225  225  900   225
# e  100  100  100  100  1200
# --[89]-----------------------------------------
#      a    b    c    d     e
# a    0  300  300  300   300
# b  200    0  200  200   200
# c   37   37  450   37    37
# d  225  225  225  900   225
# e    0    0    0    0  1600
# --[90]-----------------------------------------
#      a    b    c     d    e
# a    0  300  300   300  300
# b  200    0  200   200  200
# c   37   37  450    37   37
# d  112  112  112  1350  112
# e  400  400  400   400    0
# --[91]-----------------------------------------
#      a    b    c     d    e
# a    0  300  300   300  300
# b  200    0  200   200  200
# c   37   37  450    37   37
# d  112  112  112  1350  112
# e  300  300  300   300  400
# --[92]-----------------------------------------
#      a    b    c     d    e
# a    0  300  300   300  300
# b  200    0  200   200  200
# c   37   37  450    37   37
# d  112  112  112  1350  112
# e  200  200  200   200  800
# --[93]-----------------------------------------
#      a    b    c     d     e
# a    0  300  300   300   300
# b  200    0  200   200   200
# c   37   37  450    37    37
# d  112  112  112  1350   112
# e  100  100  100   100  1200
# --[94]-----------------------------------------
#      a    b    c     d     e
# a    0  300  300   300   300
# b  200    0  200   200   200
# c   37   37  450    37    37
# d  112  112  112  1350   112
# e    0    0    0     0  1600
# --[95]-----------------------------------------
#      a    b    c     d    e
# a    0  300  300   300  300
# b  200    0  200   200  200
# c   37   37  450    37   37
# d    0    0    0  1800    0
# e  400  400  400   400    0
# --[96]-----------------------------------------
#      a    b    c     d    e
# a    0  300  300   300  300
# b  200    0  200   200  200
# c   37   37  450    37   37
# d    0    0    0  1800    0
# e  300  300  300   300  400
# --[97]-----------------------------------------
#      a    b    c     d    e
# a    0  300  300   300  300
# b  200    0  200   200  200
# c   37   37  450    37   37
# d    0    0    0  1800    0
# e  200  200  200   200  800
# --[98]-----------------------------------------
#      a    b    c     d     e
# a    0  300  300   300   300
# b  200    0  200   200   200
# c   37   37  450    37    37
# d    0    0    0  1800     0
# e  100  100  100   100  1200
# --[99]-----------------------------------------
#      a    b    c     d     e
# a    0  300  300   300   300
# b  200    0  200   200   200
# c   37   37  450    37    37
# d    0    0    0  1800     0
# e    0    0    0     0  1600
# --[100]-----------------------------------------
#      a    b    c    d    e
# a    0  300  300  300  300
# b  200    0  200  200  200
# c    0    0  600    0    0
# d  450  450  450    0  450
# e  400  400  400  400    0
# --[101]-----------------------------------------
#      a    b    c    d    e
# a    0  300  300  300  300
# b  200    0  200  200  200
#
-----------------------------------------
#      a    b    c    d    e
# a    0  300  300  300  300
# b  150  200  150  150  150
# c   37   37  450   37   37
# d  450  450  450    0  450
# e  200  200  200  200  800
# --[203]-----------------------------------------
#      a    b    c    d     e
# a    0  300  300  300   300
# b  150  200  150  150   150
# c   37   37  450   37    37
# d  450  450  450    0   450
# e  100  100  100  100  1200
# --[204]-----------------------------------------
#      a    b    c    d     e
# a    0  300  300  300   300
# b  150  200  150  150   150
# c   37   37  450   37    37
# d  450  450  450    0   450
# e    0    0    0    0  1600
# --[205]-----------------------------------------
#      a    b    c    d    e
# a    0  300  300  300  300
# b  150  200  150  150  150
# c   37   37  450   37   37
# d  337  337  337  450  337
# e  400  400  400  400    0
# --[206]-----------------------------------------
#      a    b    c    d    e
# a    0  300  300  300  300
# b  150  200  150  150  150
# c   37   37  450   37   37
# d  337  337  337  450  337
# e  300  300  300  300  400
# --[207]-----------------------------------------
#      a    b    c    d    e
# a    0  300  300  300  300
# b  150  200  150  150  150
# c   37   37  450   37   37
# d  337  337  337  450  337
# e  200  200  200  200  800
# --[208]-----------------------------------------
#      a    b    c    d     e
# a    0  300  300  300   300
# b  150  200  150  150   150
# c   37   37  450   37    37
# d  337  337  337  450   337
# e  100  100  100  100  1200
# --[209]-----------------------------------------
#      a    b    c    d     e
# a    0  300  300  300   300
# b  150  200  150  150   150
# c   37   37  450   37    37
# d  337  337  337  450   337
# e    0    0    0    0  1600
# --[210]-----------------------------------------
#      a    b    c    d    e
# a    0  300  300  300  300
# b  150  200  150  150  150
# c   37   37  450   37   37
# d  225  225  225  900  225
# e  400  400  400  400    0
# --[211]-----------------------------------------
#      a    b    c    d    e
# a    0  300  300  300  300
# b  150  200  150  150  150
# c   37   37  450   37   37
# d  225  225  225  900  225
# e  300  300  300  300  400
# --[212]-----------------------------------------
#      a    b    c    d    e
# a    0  300  300  300  300
# b  150  200  150  150  150
# c   37   37  450   37   37
# d  225  225  225  900  225
# e  200  200  200  200  800
# --[213]-----------------------------------------
#      a    b    c    d     e
# a    0  300  300  300   300
# b  150  200  150  150   150
# c   37   37  450   37    37
# d  225  225  225  900   225
# e  100  100  100  100  1200
# --[214]-----------------------------------------
#      a    b    c    d     e
# a    0  300  300  300   300
# b  150  200  150  150   150
# c   37   37  450   37    37
# d  225  225  225  900   225
# e    0    0    0    0  1600
# --[215]-----------------------------------------
#      a    b    c     d    e
# a    0  300  300   300  300
# b  150  200  150   150  150
# c   37   37  450    37   37
# d  112  112  112  1350  112
# e  400  400  400   400    0
# --[216]-----------------------------------------
#      a    b    c     d    e
# a    0  300  300   300  300
# b  150  200  150   150  150
# c   37   37  450    37   37
# d  112  112  112  1350  112
# e  300  300  300   300  400
# --[217]-----------------------------------------
#      a    b    c     d    e
# a    0  300  300   300  300
# b  150  200  150   150  150
# c   37   37  450    37   37
# d  112  112  112  1350  112
# e  200  200  200   200  800
# --[218]-----------------------------------------
#      a    b    c     d     e
# a    0  300  300   300   300
# b  150  200  150   150   150
# c   37   37  450    37    37
# d  112  112  112  1350   112
# e  100  100  100   100  1200
# --[219]-----------------------------------------
#      a    b    c     d     e
# a    0  300  300   300   300
# b  150  200  150   150   150
# c   37   37  450    37    37
# d  112  112  112  1350   112
# e    0    0    0     0  1600
# --[220]-----------------------------------------
#      a    b    c     d    e
# a    0  300  300   300  300
# b  150  200  150   150  150
# c   37   37  450    37   37
# d    0    0    0  1800    0
# e  400  400  400   400    0
# --[221]-----------------------------------------
#      a    b    c     d    e
# a    0  300  300   300  300
# b  150  200  150   150  150
# c   37   37  450    37   37
# d    0    0    0  1800    0
# e  300  300  300   300  400
# --[222]-----------------------------------------
#      a    b    c     d    e
# a    0  300  300   300  300
# b  150  200  150   150  150
# c   37   37  450    37   37
# d    0    0    0  1800    0
# e  200  200  200   200  800
# ...
#       a    b    c    d     e
# a  1200    0    0    0     0
# b     0  800    0    0     0
# c    75   75  300   75    75
# d   450  450  450    0   450
# e   100  100  100  100  1200
# --[3054]-----------------------------------------
#       a    b    c   d     e
# a  1200    0    0   0     0
# b     0  800    0   0     0
# c    75   75  300  75    75
# d   450  450  450   0   450
# e     0    0    0   0  1600
# --[3055]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c    75   75  300   75   75
# d   337  337  337  450  337
# e   400  400  400  400    0
# --[3056]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c    75   75  300   75   75
# d   337  337  337  450  337
# e   300  300  300  300  400
# --[3057]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c    75   75  300   75   75
# d   337  337  337  450  337
# e   200  200  200  200  800
# --[3058]-----------------------------------------
#       a    b    c    d     e
# a  1200    0    0    0     0
# b     0  800    0    0     0
# c    75   75  300   75    75
# d   337  337  337  450   337
# e   100  100  100  100  1200
# --[3059]-----------------------------------------
#       a    b    c    d     e
# a  1200    0    0    0     0
# b     0  800    0    0     0
# c    75   75  300   75    75
# d   337  337  337  450   337
# e     0    0    0    0  1600
# --[3060]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c    75   75  300   75   75
# d   225  225  225  900  225
# e   400  400  400  400    0
# --[3061]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c    75   75  300   75   75
# d   225  225  225  900  225
# e   300  300  300  300  400
# --[3062]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c    75   75  300   75   75
# d   225  225  225  900  225
# e   200  200  200  200  800
# --[3063]-----------------------------------------
#       a    b    c    d     e
# a  1200    0    0    0     0
# b     0  800    0    0     0
# c    75   75  300   75    75
# d   225  225  225  900   225
# e   100  100  100  100  1200
# --[3064]-----------------------------------------
#       a    b    c    d     e
# a  1200    0    0    0     0
# b     0  800    0    0     0
# c    75   75  300   75    75
# d   225  225  225  900   225
# e     0    0    0    0  1600
# --[3065]-----------------------------------------
#       a    b    c     d    e
# a  1200    0    0     0    0
# b     0  800    0     0    0
# c    75   75  300    75   75
# d   112  112  112  1350  112
# e   400  400  400   400    0
# --[3066]-----------------------------------------
#       a    b    c     d    e
# a  1200    0    0     0    0
# b     0  800    0     0    0
# c    75   75  300    75   75
# d   112  112  112  1350  112
# e   300  300  300   300  400
# --[3067]-----------------------------------------
#       a    b    c     d    e
# a  1200    0    0     0    0
# b     0  800    0     0    0
# c    75   75  300    75   75
# d   112  112  112  1350  112
# e   200  200  200   200  800
# --[3068]-----------------------------------------
#       a    b    c     d     e
# a  1200    0    0     0     0
# b     0  800    0     0     0
# c    75   75  300    75    75
# d   112  112  112  1350   112
# e   100  100  100   100  1200
# --[3069]-----------------------------------------
#       a    b    c     d     e
# a  1200    0    0     0     0
# b     0  800    0     0     0
# c    75   75  300    75    75
# d   112  112  112  1350   112
# e     0    0    0     0  1600
# --[3070]-----------------------------------------
#       a    b    c     d   e
# a  1200    0    0     0   0
# b     0  800    0     0   0
# c    75   75  300    75  75
# d     0    0    0  1800   0
# e   400  400  400   400   0
# --[3071]-----------------------------------------
#       a    b    c     d    e
# a  1200    0    0     0    0
# b     0  800    0     0    0
# c    75   75  300    75   75
# d     0    0    0  1800    0
# e   300  300  300   300  400
# --[3072]-----------------------------------------
#       a    b    c     d    e
# a  1200    0    0     0    0
# b     0  800    0     0    0
# c    75   75  300    75   75
# d     0    0    0  1800    0
# e   200  200  200   200  800
# --[3073]-----------------------------------------
#       a    b    c     d     e
# a  1200    0    0     0     0
# b     0  800    0     0     0
# c    75   75  300    75    75
# d     0    0    0  1800     0
# e   100  100  100   100  1200
# --[3074]-----------------------------------------
#       a    b    c     d     e
# a  1200    0    0     0     0
# b     0  800    0     0     0
# c    75   75  300    75    75
# d     0    0    0  1800     0
# e     0    0    0     0  1600
# --[3075]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c    37   37  450   37   37
# d   450  450  450    0  450
# e   400  400  400  400    0
# --[3076]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c    37   37  450   37   37
# d   450  450  450    0  450
# e   300  300  300  300  400
# --[3077]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c    37   37  450   37   37
# d   450  450  450    0  450
# e   200  200  200  200  800
# --[3078]-----------------------------------------
#       a    b    c    d     e
# a  1200    0    0    0     0
# b     0  800    0    0     0
# c    37   37  450   37    37
# d   450  450  450    0   450
# e   100  100  100  100  1200
# --[3079]-----------------------------------------
#       a    b    c   d     e
# a  1200    0    0   0     0
# b     0  800    0   0     0
# c    37   37  450  37    37
# d   450  450  450   0   450
# e     0    0    0   0  1600
# --[3080]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c    37   37  450   37   37
# d   337  337  337  450  337
# e   400  400  400  400    0
# --[3081]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c    37   37  450   37   37
# d   337  337  337  450  337
# e   300  300  300  300  400
# --[3082]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c    37   37  450   37   37
# d   337  337  337  450  337
# e   200  200  200  200  800
# --[3083]-----------------------------------------
#       a    b    c    d     e
# a  1200    0    0    0     0
# b     0  800    0    0     0
# c    37   37  450   37    37
# d   337  337  337  450   337
# e   100  100  100  100  1200
# --[3084]-----------------------------------------
#       a    b    c    d     e
# a  1200    0    0    0     0
# b     0  800    0    0     0
# c    37   37  450   37    37
# d   337  337  337  450   337
# e     0    0    0    0  1600
# --[3085]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c    37   37  450   37   37
# d   225  225  225  900  225
# e   400  400  400  400    0
# --[3086]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c    37   37  450   37   37
# d   225  225  225  900  225
# e   300  300  300  300  400
# --[3087]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c    37   37  450   37   37
# d   225  225  225  900  225
# e   200  200  200  200  800
# --[3088]-----------------------------------------
#       a    b    c    d     e
# a  1200    0    0    0     0
# b     0  800    0    0     0
# c    37   37  450   37    37
# d   225  225  225  900   225
# e   100  100  100  100  1200
# --[3089]-----------------------------------------
#       a    b    c    d     e
# a  1200    0    0    0     0
# b     0  800    0    0     0
# c    37   37  450   37    37
# d   225  225  225  900   225
# e     0    0    0    0  1600
# --[3090]-----------------------------------------
#       a    b    c     d    e
# a  1200    0    0     0    0
# b     0  800    0     0    0
# c    37   37  450    37   37
# d   112  112  112  1350  112
# e   400  400  400   400    0
# --[3091]-----------------------------------------
#       a    b    c     d    e
# a  1200    0    0     0    0
# b     0  800    0     0    0
# c    37   37  450    37   37
# d   112  112  112  1350  112
# e   300  300  300   300  400
# --[3092]-----------------------------------------
#       a    b    c     d    e
# a  1200    0    0     0    0
# b     0  800    0     0    0
# c    37   37  450    37   37
# d   112  112  112  1350  112
# e   200  200  200   200  800
# --[3093]-----------------------------------------
#       a    b    c     d     e
# a  1200    0    0     0     0
# b     0  800    0     0     0
# c    37   37  450    37    37
# d   112  112  112  1350   112
# e   100  100  100   100  1200
# --[3094]-----------------------------------------
#       a    b    c     d     e
# a  1200    0    0     0     0
# b     0  800    0     0     0
# c    37   37  450    37    37
# d   112  112  112  1350   112
# e     0    0    0     0  1600
# --[3095]-----------------------------------------
#       a    b    c     d   e
# a  1200    0    0     0   0
# b     0  800    0     0   0
# c    37   37  450    37  37
# d     0    0    0  1800   0
# e   400  400  400   400   0
# --[3096]-----------------------------------------
#       a    b    c     d    e
# a  1200    0    0     0    0
# b     0  800    0     0    0
# c    37   37  450    37   37
# d     0    0    0  1800    0
# e   300  300  300   300  400
# --[3097]-----------------------------------------
#       a    b    c     d    e
# a  1200    0    0     0    0
# b     0  800    0     0    0
# c    37   37  450    37   37
# d     0    0    0  1800    0
# e   200  200  200   200  800
# --[3098]-----------------------------------------
#       a    b    c     d     e
# a  1200    0    0     0     0
# b     0  800    0     0     0
# c    37   37  450    37    37
# d     0    0    0  1800     0
# e   100  100  100   100  1200
# --[3099]-----------------------------------------
#       a    b    c     d     e
# a  1200    0    0     0     0
# b     0  800    0     0     0
# c    37   37  450    37    37
# d     0    0    0  1800     0
# e     0    0    0     0  1600
# --[3100]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c     0    0  600    0    0
# d   450  450  450    0  450
# e   400  400  400  400    0
# --[3101]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c     0    0  600    0    0
# d   450  450  450    0  450
# e   300  300  300  300  400
# --[3102]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c     0    0  600    0    0
# d   450  450  450    0  450
# e   200  200  200  200  800
# --[3103]-----------------------------------------
#       a    b    c    d     e
# a  1200    0    0    0     0
# b     0  800    0    0     0
# c     0    0  600    0     0
# d   450  450  450    0   450
# e   100  100  100  100  1200
# --[3104]-----------------------------------------
#       a    b    c  d     e
# a  1200    0    0  0     0
# b     0  800    0  0     0
# c     0    0  600  0     0
# d   450  450  450  0   450
# e     0    0    0  0  1600
# --[3105]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c     0    0  600    0    0
# d   337  337  337  450  337
# e   400  400  400  400    0
# --[3106]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c     0    0  600    0    0
# d   337  337  337  450  337
# e   300  300  300  300  400
# --[3107]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c     0    0  600    0    0
# d   337  337  337  450  337
# e   200  200  200  200  800
# --[3108]-----------------------------------------
#       a    b    c    d     e
# a  1200    0    0    0     0
# b     0  800    0    0     0
# c     0    0  600    0     0
# d   337  337  337  450   337
# e   100  100  100  100  1200
# --[3109]-----------------------------------------
#       a    b    c    d     e
# a  1200    0    0    0     0
# b     0  800    0    0     0
# c     0    0  600    0     0
# d   337  337  337  450   337
# e     0    0    0    0  1600
# --[3110]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c     0    0  600    0    0
# d   225  225  225  900  225
# e   400  400  400  400    0
# --[3111]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c     0    0  600    0    0
# d   225  225  225  900  225
# e   300  300  300  300  400
# --[3112]-----------------------------------------
#       a    b    c    d    e
# a  1200    0    0    0    0
# b     0  800    0    0    0
# c     0    0  600    0    0
# d   225  225  225  900  225
# e   200  200  200  200  800
# --[3113]-----------------------------------------
#       a    b    c    d     e
# a  1200    0    0    0     0
# b     0  800    0    0     0
# c     0    0  600    0     0
# d   225  225  225  900   225
# e   100  100  100  100  1200
# --[3114]-----------------------------------------
#       a    b    c    d     e
# a  1200    0    0    0     0
# b     0  800    0    0     0
# c     0    0  600    0     0
# d   225  225  225  900   225
# e     0    0    0    0  1600
# --[3115]-----------------------------------------
#       a    b    c     d    e
# a  1200    0    0     0    0
# b     0  800    0     0    0
# c     0    0  600     0    0
# d   112  112  112  1350  112
# e   400  400  400   400    0
# --[3116]-----------------------------------------
#       a    b    c     d    e
# a  1200    0    0     0    0
# b     0  800    0     0    0
# c     0    0  600     0    0
# d   112  112  112  1350  112
# e   300  300  300   300  400
# --[3117]-----------------------------------------
#       a    b    c     d    e
# a  1200    0    0     0    0
# b     0  800    0     0    0
# c     0    0  600     0    0
# d   112  112  112  1350  112
# e   200  200  200   200  800
# --[3118]-----------------------------------------
#       a    b    c     d     e
# a  1200    0    0     0     0
# b     0  800    0     0     0
# c     0    0  600     0     0
# d   112  112  112  1350   112
# e   100  100  100   100  1200
# --[3119]-----------------------------------------
#       a    b    c     d     e
# a  1200    0    0     0     0
# b     0  800    0     0     0
# c     0    0  600     0     0
# d   112  112  112  1350   112
# e     0    0    0     0  1600
# --[3120]-----------------------------------------
#       a    b    c     d  e
# a  1200    0    0     0  0
# b     0  800    0     0  0
# c     0    0  600     0  0
# d     0    0    0  1800  0
# e   400  400  400   400  0
# --[3121]-----------------------------------------
#       a    b    c     d    e
# a  1200    0    0     0    0
# b     0  800    0     0    0
# c     0    0  600     0    0
# d     0    0    0  1800    0
# e   300  300  300   300  400
# --[3122]-----------------------------------------
#       a    b    c     d    e
# a  1200    0    0     0    0
# b     0  800    0     0    0
# c     0    0  600     0    0
# d     0    0    0  1800    0
# e   200  200  200   200  800
# --[3123]-----------------------------------------
#       a    b    c     d     e
# a  1200    0    0     0     0
# b     0  800    0     0     0
# c     0    0  600     0     0
# d     0    0    0  1800     0
# e   100  100  100   100  1200
# --[3124]-----------------------------------------
#       a    b    c     d     e
# a  1200    0    0     0     0
# b     0  800    0     0     0
# c     0    0  600     0     0
# d     0    0    0  1800     0
# e     0    0    0     0  1600

# %% [markdown]
# As we have shown, the Confusion Matrix is capable of handling multi-class, as well as imbalanced, multi-class classification data. Let's take a deeper look into the confusion matrix itself.
#
# Let's hone in on a single matrix.

# %%
matrix = generator.all_cms[647]

print(matrix)
# Out:
#      a    b    c     d    e
# a  300  225  225   225  225
# b  200    0  200   200  200
# c  150  150    0   150  150
# d    0    0    0  1800    0
# e  200  200  200   200  800

# %%
#We can print the total instances it predicted correctly:
matrix.get_total_true()
# Out:
# np.int64(2900)

# %%
#We can also get the number of times it guessed a specific class incorrectly:
print(matrix.get_false_predictions('a'))
# Out:
# 550

# %%
#Or the number of times it guessed a different class than the given one:
print(matrix.get_missed_predictions('a'))
# Out:
# 900

# %% [markdown]
# If left blank, these functions will return a list of the number of each of their values per class:

# %%
#This will be the sum of each column, except for the diagonal.
print(matrix.get_false_predictions())
# Out:
# {'a': np.int64(550), 'b': np.int64(575), 'c': np.int64(625), 'd': np.int64(775), 'e': np.int64(575)}

# %%
#This will be the sum of each row, except for the diagonal.
print(matrix.get_missed_predictions())
# Out:
# [900 800 600   0 800]

# %% [markdown]
# We can also grab the rate at which the model predicted each class successfully:

# %%
print(matrix.positive_rates())
# Out:
# (np.float64(0.25), np.float64(0.0), np.float64(0.0), np.float64(1.0), np.float64(0.5))

# %% [markdown]
# We can also specify another data type we wish to use other than tuple:

# %%
print(matrix.positive_rates(return_type=list))
# Out:
# [np.float64(0.25), np.float64(0.0), np.float64(0.0), np.float64(1.0), np.float64(0.5)]

# %% [markdown]
# There is also a built-in normalization function:

# %%
print(matrix)

print('\n')

matrix.normalize()
print(matrix)
# Out:
#      a    b    c     d    e
# a  300  225  225   225  225
# b  200    0  200   200  200
# c  150  150    0   150  150
# d    0    0    0  1800    0
# e  200  200  200   200  800
#
#
#        a       b       c       d       e
# a  0.250  0.1875  0.1875  0.1875  0.1875
# b  0.250  0.0000  0.2500  0.2500  0.2500
# c  0.250  0.2500  0.0000  0.2500  0.2500
# d  0.000  0.0000  0.0000  1.0000  0.0000
# e  0.125  0.1250  0.1250  0.1250  0.5000

# %% [markdown]
# Let's explore using these matrices to generate a contingency space:

# %%
#We pass in a dictionary consisting of the matrices we wish to use for the contingency space. 
cs = ContingencySpace({
    '1': CMGeneralized({
        't': [500, 500], 
        'f': [500, 500]
    }),
    '2': CMGeneralized({
        't': [600, 400], 
        'f': [600, 400]
    }),
    '3': CMGeneralized({
        't': [700, 300], 
        'f': [700, 300]
    }),
    '4': CMGeneralized({
        't': [800, 200], 
        'f': [800, 200]
    }),
    '5': CMGeneralized({
        't': [900, 100], 
        'f': [900, 100]
    }),
    '6': CMGeneralized({
        't': [1000, 0], 
        'f': [1000, 100]
    })
})

# %% [markdown]
# **Learning paths (2D and 3D)**
#
# Now that we've built the contingency space, we can take a look into some of the data contained within. For example, it is capable of calculating the learning paths of the matrices in 2D and 3D (Keep in mind this is for BINARY classification):

# %%
from metrics.acc import accuracy

print("Learning path (2D):")
print(str(cs.learning_path_length_2D(('1', '6'))) + "\n")

print("Learning path (3D):")
print(str(cs.learning_path_length_3D(('1', '6'), accuracy)))
# Out:
# Learning path (2D):
# 0.6660977978327586
#
# Learning path (3D):
# 0.668882023983002

# %% [markdown]
# **Imbalance Sensitivity**
#
# Let's explore the usage of the Imbalance sensitivity function I have designed. This function takes a few arguments:
#
# First, one of a few options to give the function a ratio to work with,
# and second, a callable (function) that takes a CMGeneralized and returns a float representing the score of a given matrix within a given metric.

# %%
#First, we define a function that takes a CMGeneralized and returns a float based on the score for that given metric between 0 and 1. 
def our_accuracy(matrix: CMGeneralized) -> float:
    arr = matrix.array()

    true_values = np.sum(arr.diagonal())
    total_values = np.sum(arr)

    return true_values / total_values

#here, we will pass the denominator of the ratio, so '4' represents a 1:4 imbalance ratio.
score: float = imbalance_sensitivity(4, our_accuracy)

# %% [markdown]
# There are other options to pass this ratio to the function as well:

# %%
print(imbalance_sensitivity("1:8", our_accuracy))
print('\n')
print(imbalance_sensitivity((1, 16), our_accuracy))
print('\n')
print(imbalance_sensitivity(1.132, our_accuracy))
# Out:
# 0.13827752419753087
#
#
# 0.15686797052287582
#
#
# 0.1670049814983165

# %% [markdown]
# I have designed some basic implementations of common metrics:

# %%
from metrics.acc import accuracy
from metrics.bac import balanced_accuracy

print(imbalance_sensitivity(8, accuracy))
print(imbalance_sensitivity(4, balanced_accuracy))
# Out:
# 0.13827752419753087
# 0.0002498000000000114
